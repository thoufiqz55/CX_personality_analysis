# %% [markdown]
# <a href="https://colab.research.google.com/github/thoufiqz55/CX_personality_analysis/blob/main/marketing_campaign.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#reading the dataset
data=pd.read_csv('marketing_campaign.csv')

# %%
data.head()
# Out:
#      ID  Year_Birth   Education  ... Z_CostContact  Z_Revenue  Response
# 0  5524        1957  Graduation  ...             3         11         1
# 1  2174        1954  Graduation  ...             3         11         0
# 2  4141        1965  Graduation  ...             3         11         0
# 3  6182        1984  Graduation  ...             3         11         0
# 4  5324        1981         PhD  ...             3         11         0
#
# [5 rows x 29 columns]

# %%
data.shape
# Out:
# (2240, 29)

# %%
data.describe()
# Out:
#                  ID   Year_Birth  ...  Z_Revenue     Response
# count   2240.000000  2240.000000  ...     2240.0  2240.000000
# mean    5592.159821  1968.805804  ...       11.0     0.149107
# std     3246.662198    11.984069  ...        0.0     0.356274
# min        0.000000  1893.000000  ...       11.0     0.000000
# 25%     2828.250000  1959.000000  ...       11.0     0.000000
# 50%     5458.500000  1970.000000  ...       11.0     0.000000
# 75%     8427.750000  1977.000000  ...       11.0     0.000000
# max    11191.000000  1996.000000  ...       11.0     1.000000
#
# [8 rows x 26 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
#Checking null_values
data.isna().sum()
# Out:
# ID                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income                 24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# AcceptedCmp3            0
# AcceptedCmp4            0
# AcceptedCmp5            0
# AcceptedCmp1            0
# AcceptedCmp2            0
# Complain                0
# Z_CostContact           0
# Z_Revenue               0
# Response                0
# dtype: int64

# %%
data['Income'].fillna(data['Income'].mean(),inplace=True)

# %%
data['Income'].isna()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2235    False
# 2236    False
# 2237    False
# 2238    False
# 2239    False
# Name: Income, Length: 2240, dtype: bool

# %%
data.isna().sum()
# Out:
# ID                     0
# Year_Birth             0
# Education              0
# Marital_Status         0
# Income                 0
# Kidhome                0
# Teenhome               0
# Dt_Customer            0
# Recency                0
# MntWines               0
# MntFruits              0
# MntMeatProducts        0
# MntFishProducts        0
# MntSweetProducts       0
# MntGoldProds           0
# NumDealsPurchases      0
# NumWebPurchases        0
# NumCatalogPurchases    0
# NumStorePurchases      0
# NumWebVisitsMonth      0
# AcceptedCmp3           0
# AcceptedCmp4           0
# AcceptedCmp5           0
# AcceptedCmp1           0
# AcceptedCmp2           0
# Complain               0
# Z_CostContact          0
# Z_Revenue              0
# Response               0
# dtype: int64

# %%
#changing the Column name 
data['Age']=2022 - data['Year_Birth']

# %%
data.head(2)
# Out:
#      ID  Year_Birth   Education  ... Z_Revenue  Response  Age
# 0  5524        1957  Graduation  ...        11         1   65
# 1  2174        1954  Graduation  ...        11         0   68
#
# [2 rows x 30 columns]

# %%
data.shape
# Out:
# (2240, 30)

# %%
data.drop(['Year_Birth'], axis=1, inplace=True)

# %%
data.tail()
# Out:
#          ID   Education Marital_Status  ...  Z_Revenue  Response  Age
# 2235  10870  Graduation        Married  ...         11         0   55
# 2236   4001         PhD       Together  ...         11         0   76
# 2237   7270  Graduation       Divorced  ...         11         0   41
# 2238   8235      Master       Together  ...         11         0   66
# 2239   9405         PhD        Married  ...         11         1   68
#
# [5 rows x 29 columns]

# %%
#merging the columns 
data['Spendings']=(data['MntFishProducts'] +data['MntFruits'] +data['MntWines']+data['MntGoldProds']+data['MntMeatProducts']+data['MntSweetProducts'])

# %%
#merging the columns 
data['PurchaseNum']=(data['NumDealsPurchases']+data['NumWebPurchases']+data['NumCatalogPurchases']+data['NumStorePurchases']+data['NumWebVisitsMonth'])

# %%
data.head()
# Out:
#      ID   Education Marital_Status  ...  Age  Spendings  PurchaseNum
# 0  5524  Graduation         Single  ...   65       1617           32
# 1  2174  Graduation         Single  ...   68         27           11
# 2  4141  Graduation       Together  ...   57        776           25
# 3  6182  Graduation       Together  ...   38         53           14
# 4  5324         PhD        Married  ...   41        422           24
#
# [5 rows x 31 columns]

# %%
data.shape
# Out:
# (2240, 31)

# %%
data['Children']=(data['Kidhome']+data['Teenhome'])

# %%
#checking the unique values
data['Marital_Status'].unique()
# Out:
# array(['Single', 'Together', 'Married', 'Divorced', 'Widow', 'Alone',
#        'Absurd', 'YOLO'], dtype=object)

# %%
#replacing the values for categorical values
data['Marital_Status']=data['Marital_Status'].replace({'Married':'Couple', 'Single':'Single','Together':'Couple','Divorced':'Single','Widow':'Single','Alone':'Single','Absurd':'Single','YOLO':'Single'})

# %%
data['Marital_Status'].unique()
# Out:
# array(['Single', 'Couple'], dtype=object)

# %%
data.head(10)
# Out:
#      ID   Education Marital_Status  ...  Spendings  PurchaseNum  Children
# 0  5524  Graduation         Single  ...       1617           32         0
# 1  2174  Graduation         Single  ...         27           11         2
# 2  4141  Graduation         Couple  ...        776           25         0
# 3  6182  Graduation         Couple  ...         53           14         1
# 4  5324         PhD         Couple  ...        422           24         1
# 5  7446      Master         Couple  ...        716           28         1
# 6   965  Graduation         Single  ...        590           27         1
# 7  6177         PhD         Couple  ...        169           18         1
# 8  4855         PhD         Couple  ...         46           15         1
# 9  5899         PhD         Couple  ...         49           22         2
#
# [10 rows x 32 columns]

# %%
data['Education'].unique()
# Out:
# array(['Graduation', 'PhD', 'Master', 'Basic', '2n Cycle'], dtype=object)

# %%
data['Education']=data['Education'].replace({'2n Cycle':'Pre University','Basic':'School'})

# %%
data['Education'].unique()
# Out:
# array(['Graduation', 'PhD', 'Master', 'School', 'Pre University'],
#       dtype=object)

# %%
#plotting graph for marital status
sns.countplot(data.Marital_Status)
plt.show()

# %%
#plotting graph for Education
sns.countplot(data.Education)

# %%
#Encoding the categorical values
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()
for item in ['Education','Marital_Status']:
  data[item]=data[[item]].apply(label_encoder.fit_transform)
data.head(10)
# Out:
#      ID  Education  Marital_Status  ...  Spendings  PurchaseNum  Children
# 0  5524          0               1  ...       1617           32         0
# 1  2174          0               1  ...         27           11         2
# 2  4141          0               0  ...        776           25         0
# 3  6182          0               0  ...         53           14         1
# 4  5324          2               0  ...        422           24         1
# 5  7446          1               0  ...        716           28         1
# 6   965          0               1  ...        590           27         1
# 7  6177          2               0  ...        169           18         1
# 8  4855          2               0  ...         46           15         1
# 9  5899          2               0  ...         49           22         2
#
# [10 rows x 32 columns]

# %%
data=data.drop(['Dt_Customer','ID','Kidhome','Teenhome','MntWines','MntFruits','MntMeatProducts','MntFishProducts',
                'MntSweetProducts','MntGoldProds','NumDealsPurchases','NumWebPurchases','NumCatalogPurchases','NumStorePurchases','NumWebVisitsMonth'],axis=True)

# %%
data.columns
# Out:
# Index(['Education', 'Marital_Status', 'Income', 'Recency', 'AcceptedCmp3',
#        'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1', 'AcceptedCmp2',
#        'Complain', 'Z_CostContact', 'Z_Revenue', 'Response', 'Age',
#        'Spendings', 'PurchaseNum', 'Children'],
#       dtype='object')

# %%
data.describe()
# Out:
#          Education  Marital_Status  ...  PurchaseNum     Children
# count  2240.000000     2240.000000  ...  2240.000000  2240.000000
# mean      0.967411        0.355357  ...    20.178571     0.950446
# std       1.139768        0.478728  ...     7.293275     0.751803
# min       0.000000        0.000000  ...     0.000000     0.000000
# 25%       0.000000        0.000000  ...    14.000000     0.000000
# 50%       0.000000        0.000000  ...    19.000000     1.000000
# 75%       2.000000        1.000000  ...    25.000000     1.000000
# max       4.000000        1.000000  ...    46.000000     3.000000
#
# [8 rows x 17 columns]

# %%
data=data.drop(['Z_CostContact','Z_Revenue'],axis=True)

# %%
to_plot=['Income',"Marital_Status",'Recency','Age','Children','PurchaseNum','Spendings']
sns.pairplot(data[to_plot],hue='Marital_Status')

# %%
data=data[(data['Age']<80)]

# %%
data=data[(data['Income']<60000)]

# %%
plt.figure(figsize=(12,10))
corr1=data.corr()
sns.heatmap(corr1, annot=True)

# %%
#applying standardisation
from sklearn.preprocessing import StandardScaler

# %%
data_copied=data.copy()
scaler = StandardScaler()
scaler.fit(data_copied)
data_scaled = pd.DataFrame(scaler.transform(data_copied),columns= data_copied.columns )

# %%
data_scaled.describe()
# Out:
#           Education  Marital_Status  ...   PurchaseNum      Children
# count  1.396000e+03    1.396000e+03  ...  1.396000e+03  1.396000e+03
# mean  -4.930790e-17   -3.658328e-18  ...  1.920622e-17 -1.261328e-16
# std    1.000358e+00    1.000358e+00  ...  1.000358e+00  1.000358e+00
# min   -8.567794e-01   -7.365741e-01  ... -2.428470e+00 -1.727000e+00
# 25%   -8.567794e-01   -7.365741e-01  ... -8.286594e-01 -2.850789e-01
# 50%   -2.153915e-02   -7.365741e-01  ... -2.469101e-01 -2.850789e-01
# 75%    8.137011e-01    1.357637e+00  ...  6.257139e-01  1.156842e+00
# max    2.484181e+00    1.357637e+00  ...  3.825335e+00  2.598763e+00
#
# [8 rows x 15 columns]

# %%
data_scaled.head()
# Out:
#    Education  Marital_Status    Income  ...  Spendings  PurchaseNum  Children
# 0  -0.856779        1.357637  1.503882  ...   4.669793     2.080087 -1.727000
# 1  -0.856779        1.357637  0.598941  ...  -0.729620    -0.974097  1.156842
# 2  -0.856779       -0.736574 -0.912466  ...  -0.641328    -0.537785 -0.285079
# 3   0.813701       -0.736574  1.515775  ...   0.611743     0.916589 -0.285079
# 4  -0.856779        1.357637  1.311829  ...   1.182247     1.352901 -0.285079
#
# [5 rows x 15 columns]

# %%
#Applying Kmeans Algorithm
from sklearn.cluster import KMeans

# %%
kmeans=KMeans(n_clusters=3)

# %%
data.columns
# Out:
# Index(['Education', 'Marital_Status', 'Income', 'Recency', 'AcceptedCmp3',
#        'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1', 'AcceptedCmp2',
#        'Complain', 'Response', 'Age', 'Spendings', 'PurchaseNum', 'Children'],
#       dtype='object')

# %%
kmeans.fit(data.drop(['Education','Marital_Status','Recency','AcceptedCmp3','AcceptedCmp4','AcceptedCmp5','AcceptedCmp1',
                     'AcceptedCmp2','Complain', 'Response','Age','PurchaseNum','Children'],axis=1))
# Out:
# KMeans(n_clusters=3)

# %%
print(kmeans.cluster_centers_)
# Out:
# [[52244.27904222   460.76620825]
#  [20969.08908046    72.10057471]
#  [36937.96289425   144.7309833 ]]

# %%
y=kmeans.labels_
print(y)
# Out:
# [0 0 1 ... 2 0 0]

# %%
sns.countplot(x=kmeans.labels_, palette='Oranges')
plt.show()

# %%
plt.scatter(data_scaled['Spendings'].values,data_scaled['Income'].values, c=kmeans.labels_, cmap="rainbow")
plt.show()

# %%
import numpy as np

# %%
centers = np.array(kmeans.cluster_centers_)
plt.scatter(centers[:,0], centers[:,1], marker="x", color='k')

# %%
plt.scatter(data_scaled.iloc[:,0].values,data_scaled.iloc[:,3].values, c=kmeans.labels_, cmap="rainbow")
centers = np.array(kmeans.cluster_centers_)
plt.scatter(centers[:,0], centers[:,1], marker="x", color='k')
plt.show()

# %%
from scipy.spatial.distance import cdist, pdist
from sklearn.cluster import KMeans

# %%
K = range(1,10)
X = data.drop(['Education','Marital_Status','Recency','AcceptedCmp3','AcceptedCmp4','AcceptedCmp5','AcceptedCmp1',
                     'AcceptedCmp2','Complain', 'Response','Age','PurchaseNum','Children'],axis=1)
KM = [KMeans(n_clusters=k).fit(X) for k in K]
centroids = [k.cluster_centers_ for k in KM]
D_k = [cdist(X, cent, 'euclidean') for cent in centroids]
cIdx = [np.argmin(D,axis=1) for D in D_k]
dist = [np.min(D,axis=1) for D in D_k]
avgWithinSS = [sum(d)/X.shape[0] for d in dist]

# %%
wcss = [sum(d**2) for d in dist]
tss = sum(pdist(X)**2)/X.shape[0]
bss = tss-wcss
varExplained = bss/tss*100

# %%
##### plot ###
kIdx = 2
# elbow curve
# Set the size of the plot
plt.figure(figsize=(10,4))
plt.subplot(1, 2, 1)
plt.plot(K, avgWithinSS, 'b*-')
plt.plot(K[kIdx], avgWithinSS[kIdx], marker='o', markersize=12,
markeredgewidth=2, markeredgecolor='r', markerfacecolor='None')
plt.grid(True)
plt.xlabel('Number of clusters')
plt.ylabel('Average within-cluster sum of squares')
plt.title('Elbow for KMeans clustering')
plt.subplot(1, 2, 2)
plt.plot(K, varExplained, 'b*-')
plt.plot(K[kIdx], varExplained[kIdx], marker='o', markersize=12,
markeredgewidth=2, markeredgecolor='r', markerfacecolor='None')
plt.grid(True)
plt.xlabel('Number of clusters')
plt.ylabel('Percentage of variance explained')
plt.title('Elbow for KMeans clustering')
plt.tight_layout()

# %%
from sklearn.metrics import silhouette_samples,silhouette_score
silhouette_score(X,y)
# Out:
# 0.5755556827283194
